# %% [markdown]
# # Points

# %%
library(tidyverse)
source("Lap Wrangling/source/points.r")

# %%
points <- read_csv("season_model")

points
# Out:
# Rows: 440 Columns: 11
#
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (4): .metric, .estimator, Driver, Team
# dbl (7): Round, .estimate, race_time_milliseconds, race_time_mins, race_time...
#
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     Round .metric .estimator .estimate  race_time_milliseconds race_time_mins
# 1   16    rmse    standard    8244.506  4659130                 77.65216
# 2   10    rmse    standard   14043.819  4998205                 83.30341
# 3   11    rmse    standard    5168.355  5029589                 83.82648
# 4   14    rmse    standard   17945.357  5055526                 84.25876
# 5   18    rmse    standard    1278.865  5070250                 84.50417
# 6    4    rmse    standard    7670.133  5082756                 84.71260
# ...

# %% [markdown]
# ## Drivers' World Championship

# %%
driver_points <- points %>% 
                filter(Driver == "Charles Leclerc") %>%
                arrange(by = Round)  

name <- "Charles Leclerc"

get_points()


points
# Out:
#    Points_UTR Round Driver
# 1   35         1    Charles Leclerc
# 2   35         2    Charles Leclerc
# 3   39         3    Charles Leclerc
# 4   49         4    Charles Leclerc
# 5   61         5    Charles Leclerc
# 6   69         6    Charles Leclerc
# 7   73         7    Charles Leclerc
# 8   79         8    Charles Leclerc
# 9   94         9    Charles Leclerc
# 10 119        10    Charles Leclerc
# 11 119        11    Charles Leclerc
# 12 119        12    Charles Leclerc
# 13 144        13    Charles Leclerc
# 14 169        14    Charles Leclerc
# 15 179        15    Charles Leclerc
# 16 197        16    Charles Leclerc
# 17 209        17    Charles Leclerc
# 18 227        18    Charles Leclerc
# 19 239        19    Charles Leclerc
# 20 243        20    Charles Leclerc
# 21 268        21    Charles Leclerc
# 22 278        22    Charles Leclerc
